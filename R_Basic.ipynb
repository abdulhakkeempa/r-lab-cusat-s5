# %%
install.packages("party")
install.packages("randomForest")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘TH.data’, ‘libcoin’, ‘matrixStats’, ‘multcomp’, ‘mvtnorm’, ‘modeltools’, ‘strucchange’, ‘coin’, ‘zoo’, ‘sandwich’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(randomForest)
library(party)
# Out:
# randomForest 4.7-1.1
#
# Type rfNews() to see new features/changes/bug fixes.
#
# Loading required package: grid
#
# Loading required package: mvtnorm
#
# Loading required package: modeltools
#
# Loading required package: stats4
#
# Loading required package: strucchange
#
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
# Loading required package: sandwich

# %%
# Create the input data frame.
input.dat <- readingSkills[c(1:105),]
# Give the chart file a name.
png(file = "decision_tree.png")
# Create the tree.
 output.tree <- ctree(
 nativeSpeaker ~ age + shoeSize + score,
 data = input.dat)

# %%
plot(output.tree)
# Save the file.
dev.off()
# Out:
# png
#   3
# plot without title

# %%
x <- c(151, 174, 138, 186, 128, 136, 179, 163, 152,
131)
y <- c(63, 81, 56, 91, 47, 57, 76, 72, 62, 48)

# Apply the lm() function.
relation <- lm(y~x)

print(relation)
# Out:
# Call:
# lm(formula = y ~ x)
#
# Coefficients:
# (Intercept)            x
#    -38.4551       0.6746

# %%
setClass("Student", slots=list(name="character",
                               Roll_No="numeric"))

# 'new' keyword used to create object of
# class 'Student'
a <- new("Student", name="Adam", Roll_No=20)

# Calling object
a
# Out:
# An object of class "Student"
# Slot "name":
# [1] "Adam"
#
# Slot "Roll_No":
# [1] 20

# %%
c <- new("Student", name="")

# %%
c
# Out:
# An object of class "Student"
# Slot "name":
# [1] ""
#
# Slot "Roll_No":
# numeric(0)

# %%
b <- list(name="Hakkeem", age=20)
class(b) <- "Student"

# %%
b
# Out:
# $name
# [1] "Hakkeem"
#
# $age
# [1] 20
#
# attr(,"class")
# [1] "Student"

# %%
method(print)
# Out:
# Error in method(print): could not find function "method"
# Traceback:

# %%
var1 <- c("H", "A", "B", levels=c("A", "B", "H"))

# %%
str(factor(var1))
# Out:
#  Factor w/ 3 levels "A","B","H": 3 1 2 1 2 3
#  - attr(*, "names")= chr [1:6] "" "" "" "levels1" ...

# %%
# Numeric vector
numeric_vector <- c(1, 2, 3, 4, 5)

# Character vector
character_vector <- c("apple", "banana", "orange")

# Logical vector
logical_vector <- c(TRUE, FALSE, TRUE, 1)

# %%
print(class(numeric_vector))
print(class(character_vector))
print(class(logical_vector))
# Out:
# [1] "numeric"
# [1] "character"
# [1] "numeric"

# %%
print(logical_vector)
# Out:
# [1] 1 0 1 1

# %%
# Create a matrix
matrix_data <- matrix(c(1, 2, 3, 4, 5, 6), nrow = 2, ncol = 3)

# Accessing elements
matrix_data[1, 2]  # Access element in the first row and second column
# Out:
# [1] 3

# %%
# Create a list
my_list <- list(name = "John", age = 25, grades = c(90, 85, 92))

# Accessing elements
my_list$name  # Access the element with name "name"
# Out:
# [1] "John"

# %%
my_list
# Out:
# $name
# [1] "John"
#
# $age
# [1] 25
#
# $grades
# [1] 90 85 92

# %%
# Create a factor
my_factor <- factor(c("High", "Low", "Medium"), levels = c("Low", "Medium", "High"))
print(my_factor)
# Display levels and summary
levels(my_factor)
summary(my_factor)
# Out:
# [1] High   Low    Medium
# Levels: Low Medium High
# [1] "Low"    "Medium" "High"
#    Low Medium   High
#      1      1      1

# %%
# Create a 3D array
my_array <- array(1:24, dim = c(2, 3, 4))

# Accessing elements
my_array[1, 2, 3]  # Access element in the first row, second column, and third depth
# Out:
# [1] 15

# %%
my_array
# Out:
# , , 1
#
#      [,1] [,2] [,3]
# [1,]    1    3    5
# [2,]    2    4    6
#
# , , 2
#
#      [,1] [,2] [,3]
# [1,]    7    9   11
# [2,]    8   10   12
#
# , , 3
#
#      [,1] [,2] [,3]
# [1,]   13   15   17
# [2,]   14   16   18
#
# , , 4
#
#      [,1] [,2] [,3]
# [1,]   19   21   23
# [2,]   20   22   24

# %%
plot(1:10, type="l")
plot(1:10, type="l", col="blue")
plot(1:10, type="l", lwd=2)
# Out:
# plot without title
# plot without title
# plot without title

# %%
line1 <- c(1,2,3,4,5,10)
line2 <- c(2,5,7,8,9,10)
plot(line1, type = "l", col = "blue")
lines(line2, type="l", col = "red")
# Out:
# plot without title

# %%
plot(line1, line2)
# Out:
# plot without title

# %%
x <- c(5,7,8,7,2,2,9,4,11,12,9,6)
y <- c(99,86,87,88,111,103,87,94,78,77,85,86)
plot(x, y, main="Observation of Cars", xlab="Car age", ylab="Car speed")
# Out:
# Plot with title “Observation of Cars”

# %%
plot(1:10, main="My Graph", xlab="The x-axis", ylab="The y axis")
# Out:
# Plot with title “My Graph”

# %%
x <- c(10,20,30,40)

# Display the pie chart
pie(x)

# Create a vector of pies
x <- c(10,20,30,40)
# Out:
# plot without title

# %%
# Display the pie chart and start the first pie at 90 degrees
pie(x, init.angle = 90, clockwise = TRUE)
# Out:
# plot without title

# %%
# Create a vector of labels
mylabel <- c("Apples", "Bananas", "Cherries", "Dates")

# Display the pie chart with labels
pie(x, label = mylabel, main = "Fruits")
# Out:
# Plot with title “Fruits”

# %%
# Create a vector of colors
colors <- c("blue", "yellow", "green", "black")

# Display the pie chart with colors
pie(x, label = mylabel, main = "Fruits", col = colors)
legend("bottomright", mylabel, fill = colors)
# Out:
# Plot with title “Fruits”

# %%
# x-axis values
x <- c("A", "B", "C", "D")

# y-axis values
y <- c(2, 4, 6, 8)

barplot(y, names.arg = x)
# Out:
# plot without title

# %%
x <- c("A", "B", "C", "D")
y <- c(2, 4, 6, 8)

barplot(y, names.arg = x, col = "red", horiz=TRUE)
# Out:
# plot without title

# %%
v <-  c(9,13,21,8,36,22,12,41,31,33,19)

# Create the histogram.
hist(v,xlab = "Weight",col = "yellow",border = "blue")
# Out:
# Plot with title “Histogram of v”

# %%
v <- c(9,13,21,8,36,22,12,41,31,33,19)

# Create the histogram.
hist(v,xlab = "Weight",col = "green",border = "red", xlim = c(0,40), ylim = c(0,5))
# Out:
# Plot with title “Histogram of v”

# %%
input <- mtcars[,c('mpg','cyl')]
boxplot(mpg ~ cyl, data = mtcars, xlab = "Number of Cylinders",
   ylab = "Miles Per Gallon", main = "Mileage Data")
# Out:
# Plot with title “Mileage Data”

# %%
var1 = as.integer(readline("1st number : "))
var2 = as.integer(readline("2nd number : "))
# Out:
# 1st number : 1
# 2nd number : 2

# %%
paste("Sum: " ,print(var1+var2))
paste("Diff: ",print(var1-var2))
paste("Product: ",print(var1*var2))
paste("Division: ",print(var1/var2))
paste("Integer Div: ",print(var1%/%var2))
paste("Rem: ",print(var1%%var2))
# Out:
# [1] 3
# [1] "Sum:  3"
# [1] -1
# [1] "Diff:  -1"
# [1] 2
# [1] "Product:  2"
# [1] 0.5
# [1] "Division:  0.5"
# [1] 0
# [1] "Integer Div:  0"
# [1] 1
# [1] "Rem:  1"

# %%
c1 <- c(1,2,3,4)
c2 <- c(1,2,3,4)
c3 <- c(5,2,3,4)

# %%
c1 | c2
# Out:
# [1] TRUE TRUE TRUE TRUE

# %%
c1 & c3
# Out:
# [1] TRUE TRUE TRUE TRUE

# %%
c3
# Out:
# [1] 5 2 3 4

# %%
# Creating a vector
x <- c("female", "male", "male", "female")

# Converting the vector into a factor
gender <- factor(x)

# Printing the factor
print(gender)

# Output
# [1] female male male female
# Levels: female male
# Out:
# [1] female male   male   female
# Levels: female male

# %%
# Create a vector
x <- c(1, 2, 3, 4, 5)

# Create a list
y <- list(1, 2, 3, 4, 5)

# Create a matrix
m <- matrix(c(1, 2, 3, 4, 5, 6), nrow = 2, ncol = 5)

# Create a data frame
df <- data.frame(name = c("John", "Mary", "Peter"), age = c(20, 25, 30))
# Out:
# Warning message in matrix(c(1, 2, 3, 4, 5, 6), nrow = 2, ncol = 5):
# “data length [6] is not a sub-multiple or multiple of the number of columns [5]”

# %%
x
# Out:
# [1] 1 2 3 4 5

# %%
y
# Out:
# [[1]]
# [1] 1
#
# [[2]]
# [1] 2
#
# [[3]]
# [1] 3
#
# [[4]]
# [1] 4
#
# [[5]]
# [1] 5

# %%
m
# Out:
#      [,1] [,2] [,3] [,4] [,5]
# [1,] 1    3    5    1    3
# [2,] 2    4    6    2    4

# %%
plot(1,3)
# Out:
# plot without title

# %%
plot(c(1, 8), c(3, 10))
# Out:
# plot without title

# %%
plot(c(1, 2, 3, 4, 5), c(3, 7, 8, 9, 12))
# Out:
# plot without title

# %%
plot(1:10, main="My Graph", xlab="The x-axis", ylab="The y axis")
plot(1:10, col="red")
plot(1:10, pch=25, cex=2)
# Out:
# Plot with title “My Graph”
# plot without title
# plot without title

# %%
plot(1:10, type="l")
plot(1:10, type="l", col="blue")
plot(1:10, type="l", lwd=2)
# Out:
# plot without title
# plot without title
# plot without title

# %%
plot(1:10, type="l", lwd=5, lty=9)
# Out:
# plot without title

# %%
line1 <- c(1,2,3,4,5,10)
line2 <- c(2,5,7,8,9,10)
plot(line1, type = "l", col = "blue")
lines(line2, type="l", col = "red")
# Out:
# plot without title

# %%
x <- c(5,7,8,7,2,2,9,4,11,12,9,6)
y <- c(99,86,87,88,111,103,87,94,78,77,85,86)
plot(x, y, main="Observation of Cars", xlab="Car age", ylab="Car speed")
# Out:
# Plot with title “Observation of Cars”

# %%
pie(x)
# Out:
# plot without title

# %%
# Create a vector of pies
x <- c(10,20,30,40)

# Display the pie chart and start the first pie at 90 degrees
pie(x, init.angle = 45)
pie(x)
# Out:
# plot without title
# plot without title

# %%
x <- c(10,20,30,40)

# Create a vector of labels
mylabel <- c("Apples", "Bananas", "Cherries", "Dates")

# Display the pie chart with labels
pie(x, label = mylabel, main = "Fruits")
# Out:
# Plot with title “Fruits”

# %%
# Create a vector of colors
colors <- c("blue", "yellow", "green", "black")

# Display the pie chart with colors
pie(x, label = mylabel, main = "Fruits", col = colors)
# Out:
# Plot with title “Fruits”

# %%
# Create a vector of colors
colors <- c("blue", "yellow", "green", "black")

# Display the pie chart with colors
pie(x, label = mylabel, main = "Fruits", col = colors)
legend("bottomright", mylabel, fill = colors)
# Out:
# Plot with title “Fruits”

# %%
# x-axis values
x <- c("A", "B", "C", "D")

# y-axis values
y <- c(2, 4, 6, 8)

barplot(y, names.arg = x)
# Out:
# plot without title

# %%
x <- c("A", "B", "C", "D")
y <- c(2, 4, 6, 8)

barplot(y, names.arg = x, col = "red")
# Out:
# plot without title

# %%
x <- c("A", "B", "C", "D")
y <- c(2, 4, 6, 8)

barplot(y, names.arg = x, horiz = TRUE)
# Out:
# plot without title

# %%
v <-  c(9,13,21,8,36,22,12,41,31,33,19)

# Create the histogram.
hist(v,xlab = "Weight",col = "yellow",border = "blue")
# Out:
# Plot with title “Histogram of v”

# %%
v <- c(9,13,21,8,36,22,12,41,31,33,19)

# Create the histogram.
hist(v,xlab = "Weight",col = "green",border = "red", xlim = c(0,40), ylim = c(0,5),
   breaks = 5)
# Out:
# Plot with title “Histogram of v”

# %%
input <- mtcars[,c('mpg','cyl')]
boxplot(mpg ~ cyl, data = mtcars, xlab = "Number of Cylinders",
   ylab = "Miles Per Gallon", main = "Mileage Data")
# Out:
# Plot with title “Mileage Data”

# %% [markdown]
# # Objects

# %% [markdown]
# ## S3 Class

# %%
studentBio <- list(studentName = "Harry Potter", studentAge = 19, studentContact="London")
class(studentBio) <- "StudentInfo"
studentBio
# Out:
# $studentName
# [1] "Harry Potter"
#
# $studentAge
# [1] 19
#
# $studentContact
# [1] "London"
#
# attr(,"class")
# [1] "StudentInfo"

# %% [markdown]
# ## S4 Class

# %%
setClass("employee", slots=list(name="character", id="numeric", contact="character"))

# %%
obj <- new("employee",name="Steven", id=1002, contact="West Avenue")
obj
# Out:
# An object of class "employee"
# Slot "name":
# [1] "Steven"
#
# Slot "id":
# [1] 1002
#
# Slot "contact":
# [1] "West Avenue"

# %%
setMethod("show", "employee", function(object) {
  cat("Name:",object@name, "\n")
  cat("Id:",object@id, "\n")
  cat("Contact:", object@contact, "\n")
})
obj
# Out:
# Name: Steven
# Id: 1002
# Contact: West Avenue

# %%
obj
# Out:
# An object of class "employee"
# Slot "name":
# [1] "Steven"
#
# Slot "id":
# [1] 1002
#
# Slot "contact":
# [1] "West Avenue"

# %% [markdown]
# ## Reference Class

# %%
student <-setRefClass("student", fields = list(name = "character", age = "numeric", GPA = "numeric"))

# %%
s <- student(name = "John", age = 21, GPA = 3.5)
s
# Out:
# Reference class object of class "student"
# Field "name":
# [1] "John"
# Field "age":
# [1] 21
# Field "GPA":
# [1] 3.5

# %%
d <- s

# %%
s$name <- "Hakkeem"
s
# Out:
# Reference class object of class "student"
# Field "name":
# [1] "Hakkeem"
# Field "age":
# [1] 21
# Field "GPA":
# [1] 3.5

# %%
d # reference is passed, so d gets modified along with s
# Out:
# Reference class object of class "student"
# Field "name":
# [1] "Hakkeem"
# Field "age":
# [1] 21
# Field "GPA":
# [1] 3.5
